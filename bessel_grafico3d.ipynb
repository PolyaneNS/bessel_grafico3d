# %% [markdown]
# <a href="https://colab.research.google.com/github/PolyaneNS/bessel_grafico3d/blob/master/bessel_grafico3d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
    epsilon_0 = 8.854*10**12; #F/m
    k_b = 1.380*(1/10**23); #J/K
    t = 1000; #K
    n_e = 10**19; #m
    e = 1.6*(1/10**19); #C
    r = 5*10**(-9) #cm ou 59 pm {considerando um  gás Hidrogeio(H)} 
    lambd = (epsilon_0*k_b*t)/(n_e*e**2);    
    g = np.sin(np.sqrt(x ** 2 + y ** 2))
    h = g/np.sqrt(x ** 2 + y ** 2)
    return  h + np.sqrt(lambd)

x = np.linspace(-9, 9, 1000)
y = np.linspace(-9, 9, 1000)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
